# %% [markdown]
# NAME: WALEED ABDULLAH
#
# EMAIL:  abdullah.waheed.1848@gmail.com

# %% [markdown]
# ### **PROJECT 2:**
#
# ### **SALES STORE DATA ANALYSIS**
#
# ### **OBJECTIVE:**
#
# + To analyze the store's sales info to find out how we can make your profit even better in different prospect ..

# %% [markdown]
# **Import Libraries**

# %%
#import libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Import Dataset**

# %%
#import dataset 
Store_profit='SalesStore.csv'
df=pd.read_csv(Store_profit)
df
# Out:
#      Order_Date   Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 1    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10023012
# 2    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10002828
# 3    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 4    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10000482
# ..          ...         ...       ...          ...      ...               ...
# 211  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 212  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10022901
# 213  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10002727
# 214  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 215  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10000481
#
# ...

# %%
#To check datatypes of columns
df.dtypes
# Out:
# Order_Date            object
# Ship_Date             object
# Ship_Mode             object
# Postal_Code            int64
# Region                object
# Product_Reference     object
# Category              object
# Sub_Category          object
# Sales                  int64
# Quantity               int64
# Profit               float64
# State                 object
# dtype: object

# %%
#To check unique value of a column
df.Profit.unique()
# Out:
# array([ 0.15, 10.  , 14.  ,  4.  ,  2.  ,  9.  ,  2.4 ,  6.  ,  0.4 ,
#        16.  ,  0.36, 18.  ,  1.  ,  7.  ,  8.  ,  0.3 ,  3.  ,  5.  ,
#        12.  , 17.  ,  0.2 , 11.  ,  0.9 ,  3.6 ,  0.24,  5.6 ,  0.75])

# %%
#Now check information about columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_Date         216 non-null    object
#  1   Ship_Date          216 non-null    object
#  2   Ship_Mode          216 non-null    object
#  3   Postal_Code        216 non-null    int64
#  4   Region             216 non-null    object
#  5   Product_Reference  216 non-null    object
#  6   Category           216 non-null    object
#  7   Sub_Category       216 non-null    object
#  8   Sales              216 non-null    int64
#  9   Quantity           216 non-null    int64
#  10  Profit             216 non-null    float64
#  11  State              216 non-null    object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 20.4+ KB

# %%
#To check column names
df.columns
# Out:
# Index(['Order_Date', 'Ship_Date', 'Ship_Mode', 'Postal_Code', 'Region',
#        'Product_Reference', 'Category', 'Sub_Category', 'Sales', 'Quantity',
#        'Profit', 'State'],
#       dtype='object')

# %% [markdown]
# ## **Data cleaning** ##

# %%
df.isnull().sum()
# Out:
# Order_Date           0
# Ship_Date            0
# Ship_Mode            0
# Postal_Code          0
# Region               0
# Product_Reference    0
# Category             0
# Sub_Category         0
# Sales                0
# Quantity             0
# Profit               0
# State                0
# dtype: int64

# %% [markdown]
# # **EDA (EXPLORATRY DATA ANALYSIS)**

# %%
df.Ship_Mode.unique()
# Out:
# array(['Ground', 'Air'], dtype=object)

# %% [markdown]
# **DATA ANALYSIS OF SHIP MODE**

# %%
plt.figure(figsize=(5,5))
df1=sns.countplot(data=df, x='Ship_Mode', hue='Ship_Mode')
df1.bar_label(df1.containers[0])
df1.bar_label(df1.containers[1])
plt.show()

# %%
df1=df.groupby(['Ship_Mode'], as_index=False).sum().sort_values(by='Profit', ascending=False)
plt.figure(figsize=(5,5))
df1=sns.barplot(data=df1, x='Ship_Mode',y='Profit', hue='Ship_Mode' )
df1.bar_label(df1.containers[0])
df1.bar_label(df1.containers[1])
plt.show()

# %% [markdown]
# *The visual representation illustrates that the `Ground Level (shipping mode)` has yielded higher profits compared to the ` Air level (shipping mode)`.*

# %% [markdown]
# **DATA ANALYSIS OF REGION**

# %%
plt.figure(figsize=(5,5))
df1=sns.countplot(data=df, x='Region',order=df["Region"].value_counts().index, palette='Set1')
df1.bar_label(df1.containers[1])
df1.bar_label(df1.containers[2])
df1.bar_label(df1.containers[3])
df1.bar_label(df1.containers[0])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7072\1799369719.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   df1=sns.countplot(data=df, x='Region',order=df["Region"].value_counts().index, palette='Set1')

# %%
df1=df.groupby(['Region'], as_index=False)['Profit'].sum().sort_values(by="Profit", ascending=False)
plt.figure(figsize=(5,5))
regions = df1['Region']
profits = df1['Profit']
plt.pie(profits, labels=regions, autopct="%1.2f%%", startangle=90)
plt.title('Profit Distribution by Region')
plt.show()

# %% [markdown]
# *The graphical representation indicates that the profits generated in the `South Region` surpass those of the remaining `regions`.*

# %% [markdown]
# **DATA ANALYSIS OF CATEGORY**

# %%
plt.figure(figsize=(5,5))
df1=sns.countplot(data=df, x='Category', hue='Category')
df1.bar_label(df1.containers[0])
df1.bar_label(df1.containers[1])
df1.bar_label(df1.containers[2])
plt.show()

# %%
df1=df.groupby(['Category'], as_index=False)['Profit'].sum()
plt.figure(figsize=(5,5))
df1=sns.stripplot(data=df1, x='Category',y='Profit',hue='Category')
plt.show()

# %% [markdown]
# *The graphs depict a higher profit margin from the `'Furniture and Electronics'` category in comparison to the profits generated by `'Office Supplies'`.*

# %% [markdown]
# **DATA ANALYSIS OF SUB_CATEGORY**

# %%
plt.figure(figsize=(10,10))
df1=sns.countplot(data=df, x='Sub_Category', hue='Sub_Category')
for bars in df1.containers:
    df1.bar_label(bars)
plt.xticks(rotation=90, ha='right') 
plt.show()

# %%
df1=df.groupby(['Sub_Category'], as_index=False)['Profit'].sum()
plt.figure(figsize=(10,10))
df1=sns.scatterplot(data=df1, x='Sub_Category',y='Profit', hue='Sub_Category')
plt.xticks(rotation=90, ha='right') 
plt.show()

# %% [markdown]
# *The profit analysis from the visual data suggests that `'Laptops'` outperformed other items in terms of generating revenue.*

# %% [markdown]
# **DATA ANALYSIS OF STATE**

# %%
plt.figure(figsize=(5,5))
df1=sns.countplot(data=df, x='State',hue='State')
for bars in df1.containers:
    df1.bar_label(bars)
plt.show()

# %%
df1=df.groupby(['State'], as_index=False)['Profit'].sum()
plt.figure(figsize=(10,10))
df1=sns.catplot(data=df1, x='State',y='Profit',hue='State')
plt.show()

# %% [markdown]
# *The graph highlights that doing business in 'Texas and Illinois' is more lucrative than in other states.*

# %% [markdown]
# **DATA ANALYSIS OF SUb_CATEGORY**

# %%
plt.figure(figsize=(10,10))
df1=sns.countplot(data=df, x='Sales', hue='Sales')
for bars in df1.containers:
    df1.bar_label(bars)
plt.show()

# %%
df1=df.groupby(['Sub_Category'], as_index=False)['Sales'].sum().sort_values(by='Sub_Category')
plt.figure(figsize=(10,10))
df1=sns.barplot(data=df1, x='Sub_Category',y='Sales', hue='Sub_Category')
 
plt.xticks(rotation=90, ha='right') 
plt.show()

# %% [markdown]
# *from the above grapgh we concluded that `laptops` sold more than other things*

# %% [markdown]
# **DATA ANALYSIS OF SALES**

# %%
df1=df.groupby(['Sales'], as_index=False)['Postal_Code'].sum()
plt.figure(figsize=(5,5))
df1=sns.histplot(data=df1, y='Postal_Code',x='Sales')
plt.xticks(rotation=90, ha='right') 
plt.show()

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# *After looking at all the data, we concluded that most of the sales are from `ELECTRONICS` in which `LAPTOPS and CAMERAS` Yeilded high profit than other things, this Suggest that People buy more products in these states`(TEXAS and ILLINIOS)`*
#
#
# *So `TEXAS AND ILLINIOS` are best states for doing business.............*
